# %%
import csv
import requests
import numpy as np
import pandas as pd
from io import StringIO
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import datetime

plt.close('all')

# %%
CSV_URL = 'https://covidtracking.com/api/v1/states/daily.csv'

with requests.Session() as s:
    download = s.get(CSV_URL)
    
    download

# %%
    decoded_content = download.content.decode('utf-8')

# %%
    #cr = csv.reader(decoded_content.splitlines(), delimiter=',')
    cr = pd.read_csv(StringIO(decoded_content))
    df = pd.DataFrame(cr)

# %%
df.head()
# Out:
#        date state  positive  negative  pending  hospitalizedCurrently  \
# 0  20200703    AK    1063.0  119145.0      NaN                   25.0
# 1  20200703    AL   41865.0  388766.0      NaN                  812.0
# 2  20200703    AR   22622.0  308615.0      NaN                  285.0
# 3  20200703    AS       0.0     696.0      NaN                    NaN
# 4  20200703    AZ   91858.0  486523.0      NaN                 3013.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                     NaN             NaN              NaN
# 1                  2883.0             NaN            838.0
# 2                  1517.0             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                  5018.0           741.0              NaN
#
#    onVentilatorCurrently  ...  posNeg  deathIncrease hospitalizedIncrease  \
# 0                    3.0  ...  120208              1                    0
# 1                    NaN  ...  430631             21                   48
# 2                   70.0  ...  331237              2                   40
# 3                    NaN  ...     696              0                    0
# 4                  489.0  ...  578381             31                  102
#
#                                        hash commercialScore  \
# 0  fab1145c346d70ae703d92bac3676bff80ea5b24               0
# 1  006e67beae01e0951e200fa82656c58a1c14cd70               0
# 2  763acfae6de0f8e0286ba20d9bc32cb65140d0d0               0
# 3  58e291468f971e8a0ec0c5bfa8d56fc8e202a69e               0
# 4  6f8c2473baf5cfc6b187c3a5425c301a4d645524               0
#
#   negativeRegularScore  negativeScore  positiveScore score  grade
# 0                    0              0              0     0    NaN
# 1                    0              0              0     0    NaN
# 2                    0              0              0     0    NaN
# 3                    0              0              0     0    NaN
# 4                    0              0              0     0    NaN
#
# [5 rows x 39 columns]

# %%
date = pd.to_datetime(df['date'].astype(str), format='%Y%m%d')

# %%
df3 = pd.DataFrame({'date':date, 'state':df['state'], 'positiveIncrease':df['positiveIncrease']})

# %%
stateNames = ['FL', 'GA', 'SC', 'LA', 'AL','MI', 'WA', 'CA']
dfstates = []

# %%
for name in stateNames:
    sel = df3[(df3['state']==name)]
    sel.index=sel['date']
    dfstates.insert(0, sel)

s = 'positiveIncrease'
dfgroup = pd.DataFrame()
#dfgroup['date'] = dfstates[0]['date']

for d in dfstates:
    dfgroup[d['state'][0]] = d[s]

dfgroup.head()
# Out:
#               CA   WA   MI      AL      LA    SC    GA     FL
# date
# 2020-07-03  8040  716  497  1754.0  1728.0  1831  2784   9488
# 2020-07-02  7538  611  589  1149.0  1383.0  1782  3472  10109
# 2020-07-01  9740  571  361   917.0  2083.0  1520  2946   6563
# 2020-06-30  6367  501  505   870.0  1014.0  1755  1874   6093
# 2020-06-29  5307  348  277  1734.0   845.0  1324  2207   5266

# %%
nrows = dfgroup.shape[0]
nrows
# Out:
# 122

# %%
ncols = dfgroup.shape[1]
ncols
# Out:
# 8

# %%
#fig = plt.figure();
plt.style.use('fivethirtyeight')
plot = dfgroup.plot(subplots=True, layout=(6,6), figsize=(30,20), sharex=True, sharey=False)

# %%
#plt.style.use('default')
fig, ax = plt.subplots(int(ncols/2), ncols=2)
for r in range(2):
   for d in range(int(ncols/2)):
    ax[d, r].plot(dfgroup.iloc[0:, d])
    ax[d, r].set_xlabel('date')
    ax[d, r].grid(False)
    ax[d, r].set_xticklabels('')
    ax[d, r].set_yticklabels('')
    ax[d, r].set_title(dfgroup.columns[d])

# %%
gs = gridspec.GridSpec(4, 2)

def do_plot(ax, n):
    ax.plot(dfgroup.iloc[0:, n])
    ax.set_xlabel('')
    ax.grid(False)
    ax.set_xticklabels('')
    ax.set_yticklabels('')
    ax.set_title('')
    plt.text(0, 1, dfgroup.columns[n],
         horizontalalignment='left',
         fontsize=10,
         transform = ax.transAxes)

# %%
fig = plt.figure()
for n in range(ncols):
    ax = fig.add_subplot(gs[n])
    do_plot(ax, n)
